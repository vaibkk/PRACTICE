# %%
import pandas as pd
import numpy as np

# %%
airports = pd.read_csv("C:/Users/vaibh/Machine Learning/DataSets/Programming-for-Analytics--MPBA-G507-main/Programming-for-Analytics--MPBA-G507-main/Datasets/list-of-airports-in-india-hxl-tags-1.csv")

# %%
airports = airports.drop(index=0)

# %%
airports=airports[(airports["type"] != "closed")]

# %%
airports['latitude_deg'] = airports['latitude_deg'].astype(str).astype(float).astype(int)
airports['latitude_deg']= round(airports['latitude_deg'])

# %%
type(airports.latitude_deg)
# Out:
# pandas.core.series.Series

# %%
airports.dtypes
# Out:
# id                   object
# ident                object
# type                 object
# name                 object
# latitude_deg          int32
# longitude_deg        object
# elevation_ft         object
# continent            object
# iso_country          object
# iso_region           object
# municipality         object
# scheduled_service    object
# gps_code             object
# iata_code            object
# local_code           object
# home_link            object
# wikipedia_link       object
# keywords             object
# score                object
# last_updated         object
# dtype: object

# %%
airports
# Out:
#          id    ident           type  \
# 1     26555     VIDP  large_airport
# 2     26434     VABB  large_airport
# 3     35145     VOBL  large_airport
# 4     26618     VOMM  large_airport
# 5     26444     VAGO  large_airport
# ..      ...      ...            ...
# 340   46625  IN-0062  small_airport
# 341   46640  IN-0064  small_airport
# 342   46561  IN-0038       heliport
# 343  319166  IN-0101  small_airport
# 344   46557  IN-0034  small_airport
#
#                                           name  latitude_deg longitude_deg  \
# 1          Indira Gandhi International Airport            28     77.103104
# 2    Chhatrapati Shivaji International Airport            19   72.86789703
# 3             Kempegowda International Airport            13     77.706299
# 4                Chennai International Airport            12   80.16929626
# 5                              Dabolim Airport            15   73.83139801
# ...

# %%
new=airports.groupby(['type']).count()

# %%
airports[['Date','Time']] = airports.last_updated.apply(lambda x: pd.Series(str(x).split("T")))

# %%
airports
# Out:
#          id    ident           type  \
# 1     26555     VIDP  large_airport
# 2     26434     VABB  large_airport
# 3     35145     VOBL  large_airport
# 4     26618     VOMM  large_airport
# 5     26444     VAGO  large_airport
# ..      ...      ...            ...
# 340   46625  IN-0062  small_airport
# 341   46640  IN-0064  small_airport
# 342   46561  IN-0038       heliport
# 343  319166  IN-0101  small_airport
# 344   46557  IN-0034  small_airport
#
#                                           name  latitude_deg longitude_deg  \
# 1          Indira Gandhi International Airport            28     77.103104
# 2    Chhatrapati Shivaji International Airport            19   72.86789703
# 3             Kempegowda International Airport            13     77.706299
# 4                Chennai International Airport            12   80.16929626
# 5                              Dabolim Airport            15   73.83139801
# ...
